# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats
import sys
from Functions import *
import Functions
from matplotlib.ticker import PercentFormatter
import math
import datetime
import importlib
sns.set(font_scale=2)
sns.set_style("white")

# %%
rolling_weeks = create_rooling_data(data)
rolling_weeks["Week"] = rolling_weeks.start_day.apply(lambda x: x[5:])
rolling_weeks["CI_l"] = rolling_weeks["mean"] - 1.96*(rolling_weeks["std"] / rolling_weeks["count"].apply(math.sqrt))
rolling_weeks["CI_h"] = rolling_weeks["mean"] + 1.96*(rolling_weeks["std"] / rolling_weeks["count"].apply(math.sqrt))
# Out:
# 2020-12-02 2020-12-08
# 2020-12-03 2020-12-09
# 2020-12-04 2020-12-10
# 2020-12-05 2020-12-11
# 2020-12-06 2020-12-12
# 2020-12-07 2020-12-13
# 2020-12-08 2020-12-14
# 2020-12-09 2020-12-15
# 2020-12-10 2020-12-16
# 2020-12-11 2020-12-17
# 2020-12-12 2020-12-18
# 2020-12-13 2020-12-19
# 2020-12-14 2020-12-20
# 2020-12-15 2020-12-21
# 2020-12-16 2020-12-22
# 2020-12-17 2020-12-23
# 2020-12-18 2020-12-24
# 2020-12-19 2020-12-25
# 2020-12-20 2020-12-26
# 2020-12-21 2020-12-27
# 2020-12-22 2020-12-28
# 2020-12-23 2020-12-29
# 2020-12-24 2020-12-30
# 2020-12-25 2020-12-31
# 2020-12-26 2021-01-01
# 2020-12-27 2021-01-02
# 2020-12-28 2021-01-03
# 2020-12-29 2021-01-04
# 2020-12-30 2021-01-05
# 2020-12-31 2021-01-06
# 2021-01-01 2021-01-07
# 2021-01-02 2021-01-08
# 2021-01-03 2021-01-09
# 2021-01-04 2021-01-10
# 2021-01-05 2021-01-11
# 2021-01-06 2021-01-12
# 2021-01-07 2021-01-13
# 2021-01-08 2021-01-14
# 2021-01-09 2021-01-15
# 2021-01-10 2021-01-16
# 2021-01-11 2021-01-17
# ...

# %%
plt1(rolling_weeks)

# %%
plt2(data)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# dec_end_under 60 v.s. dec_end_above 60: t-test independent samples with Bonferroni correction, P_val=1.634e-01 stat=2.046e+00
# dec_start_under 60 v.s. dec_start_above 60: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-8.272e-01
# jan_start_under 60 v.s. jan_start_above 60: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-8.526e-01
# jan_end_under 60 v.s. jan_end_above 60: t-test independent samples with Bonferroni correction, P_val=9.770e-05 stat=-4.226e+00
